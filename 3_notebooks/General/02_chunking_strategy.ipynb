# %% [markdown]
# # 02 · Chunking Strategy Comparison
# Run once on 1K papers. Confirms sentence-window wins. Feeds Table 1 of paper.

# %%
# This notebook already has results from the old tier_1 run.
# Results are in: 4_results/tier1/chunking_boundary_quality.csv
# Re-run only if you want to verify on a fresh sample.
import pandas as pd
df = pd.read_csv("../../4_results/tier1/chunking_boundary_quality.csv")
print("Existing chunking results:")
print(df)
print("\nWinner: sentence_window (highest clean_both_pct)")

# %% [markdown]
# ## Result (already confirmed)
# | Strategy | Chunks | Clean Both % |
# |----------|--------|-------------|
# | Fixed char | 629 | 69.2% |
# | Fixed token | 535 | 81.9% |
# | **Sentence window** | **519** | **85.4%** |
# | Paragraph | 500 | 84.8% |
#
# Sentence-window with 400-token target, 50-token overlap is the winner.
# This feeds directly into Table 1 of the paper. No need to rerun unless
# re-verifying from scratch.
